# %% [markdown]
# # K-Means
# - Common clustering technique, helps to solve many problems efficiently.
# - K-Means is an example of Hard Clustering, where every point belongs only to one cluster.
#
# ## Motivation Problem - *Pizza Parlour Study*
#
# **Problem Statement** Given the list of locations of customers who frequently order Pizza we want to find out optimal locations of Pizza Parlours where they should be opened.
#
# <img src="pizza1.png" alt="Pizza-1" style="width: 400px;"/>
#
# **Step-1** : Initialise Pizza Parlour Centers randomly.
# <img src="pizza2.png" alt="Pizza-2" style="width: 400px;"/>
#
# **Step-2** : Assign each customer to its nearest Pizza Center.
# <img src="pizza3.png" alt="Pizza-3" style="width: 400px;"/>
#
# **Step-3** : Update the Center Location by taking mean of customers assigned to it.
# <img src="pizza4.png" alt="Pizza-4" style="width: 400px;"/>
#
# **Step-4** : Repeat Steps 2 and 3 Until Convergence.
# <img src="pizza5.png" alt="Pizza-5" style="width: 400px;"/>

# %% [markdown]
# ## K-Means Algorithm
#
# **Input Data** : X = {x1,...,xN}
#
# **Goal** : Partition the data among some K number of clusters. Let us assume K is known to us.
#
# Let µk denote the center of Kth Cluster (uk will be vector)
#
# So we need to ﬁnd an assignment of data points to clusters,
# as well as a set of cluster centers{µk}, such that the sum of the squares
# of the distances of each data point to its closest cluster center µk, is a minimum.

# %% [markdown]
# <img src="k-means.png" alt="Pizza-1" style="width: 600px;"/>

# %% [markdown]
# ## Implementation

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# ## Dataset preperation
# - Since it is an <b>UNSUPERVISED LEARNING</b> algorithm so we will make use of only the X values to train the model and to plot graphs , although we have the y-values but we won't be useing them for the trainig purpose as it is an unsupervised learning algorithm

# %%
X,y = make_blobs?

# %%
X,y = make_blobs

# %%
X,y  = make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k = 5

color  = ["green","red","blue","yellow","orange"]

clusters = {}

for i in range(k):
    center = 10*(2*np.random.random((X.shape[1],))-1)
    points = []
    
    cluster = {
        'center':center,
        'points':points,
        'color': color[i]
        }
    
    clusters[i] = cluster

# %%
#center = 10*(2*np.random.random_sample((X.shape[1],))-1)
#print(center)

# %%
#clusters

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
#v1 = np.array([1,2])
#v2 = np.array([3,5])
#distance(v1,v2)

# %%
# Step 1:Assign every data point to one of the clusters
def assignPointToClusters(clusters): #E-Step
    for ix in range(X.shape[0]):
        dist = []
        curr_x = X[ix]

        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)

        current_cluster = np.argmin(dist)    
        clusters[current_cluster]['points'].append(curr_x)

#Step 2:        
def updateClusters(clusters): # M-Step -> We update every cluster center according to the mean of the points in it
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        
        if pts.shape[0]>0: # if cluster has some non-zero points
            new_u = pts.mean(axis=0) # axis=0 means that taking means along the columns.In short (uk=ux,uy),where ux is the mean of the x-coordinates of all the point in the points list of the center, and uy is the mean of the y-coordinates of all the points in the points list of the of the center
            clusters[kx]['center'] = new_u
            clusters[kx]['points'] = [] # we will again initialize points list to empty list ie clear the list ,as we will again repeat E-step to fill the list according to the new centers obtained
                    
def plotClusters(clusters):
    
    for kx in range(k):
        #print(len(clusters[kx]['points']))
        
        pts = np.array(clusters[kx]['points'])
        print(pts.shape) # shape=(number of points,number of features of each point)
        
        #Plot the points
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        #Plot the cluster center
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
plotClusters(clusters)
# Out:
# (128, 2)
# (72, 2)
# (196, 2)
# (1, 2)
# (103, 2)

# %%
# Initial State
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (256, 2)
# (144, 2)
# (392, 2)
# (2, 2)
# (206, 2)

# %%
# 1st iteration
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (102, 2)
# (149, 2)
# (44, 2)
# (105, 2)

# %%
# 2nd iteration
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (100, 2)
# (103, 2)
# (93, 2)
# (104, 2)

# %%
# 3rd iteration
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (100, 2)
# (103, 2)
# (98, 2)
# (99, 2)

# %%
# 4th iteration
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (100, 2)
# (103, 2)
# (98, 2)
# (99, 2)

# %% [markdown]
# Given this type of dataset where the labels were not known our algorithm was able to group similar data together to form clusters , and this is how the K-means algorithm works
